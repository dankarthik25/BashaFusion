# %%
import pandas as pd

path = 'IAST.xlsx'

# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
alphabets = pd.read_excel(path,sheet_name='IndianAlphabet')
alphabets.drop(['index'], axis=1, inplace=True) 
# alphabets.set_index('ISO',inplace=True)
print(alphabets.columns) # 'index '  
display(alphabets)
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
barakhadi = pd.read_excel(path,sheet_name='Barakhadi')
print(barakhadi.columns)
display(barakhadi)
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
import sqlite3
connect = sqlite3.connect('iast-token.db')
alphabets.to_sql('IndianAlphabet', connect, if_exists='replace',index=False)
barakhadi.to_sql('Barakhadi', connect, if_exists='replace',index=False)
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)
# Out:
# Index(['IAST', 'Devanagari', 'Bengali–Assamese', 'Gujarati', 'Gurmukhi',
#        'Kannada', 'Malayalam', 'Nastaliq', 'Odia', 'Sinhala', 'Tamil',
#        'Telugu'],
#       dtype='object')
#      IAST Devanagari Bengali–Assamese Gujarati Gurmukhi Kannada Malayalam  \
# 0       a          अ                অ        અ        ਅ       ಅ         അ
# 1       ā          आ                আ        આ        ਆ       ಆ         ആ
# 2       ạ          ॳ              NaN      NaN      NaN     NaN       NaN
# 3      ạ̄          ॴ              NaN      NaN      NaN     NaN       NaN
# 4       ụ          ॶ              NaN      NaN      NaN     NaN       NaN
# ..    ...        ...              ...      ...      ...     ...       ...
# 116   100        NaN              NaN      NaN      NaN     NaN       NaN
# 117  1000        NaN              NaN      NaN      NaN     NaN       NaN
# 118     |          ।              NaN      NaN      NaN     NaN       NaN
# ...

# %%
import sqlite3
import sys
db_connect = sqlite3.connect('iast-token.db')
query ='SELECT * FROM IndianAlphabet'

def set_query(db_connect,query):
    db_cursor = db_connect.cursor()
    try :
        db_cursor.execute(query)    
    except sqlite3.Error as e:
        print('SQLite error: %s' % (' '.join(e.args)))
        print("Exception class is: ", e.__class__)
        print('SQLite traceback: ')
        exc_type, exc_value, exc_tb = sys.exc_info()
        data = []
    
    finally:
        db_connect.commit()
        # auto_increment and delete on cascade https://stackoverflow.com/questions/29037793/sqlite-integrityerror-unique-constraint-failed
        db_cursor.close()
        # db_cursor.close()
        # print('Read Query!')
    return data
    
def get_query(db_connect,query):
    db_cursor = db_connect.cursor()
    try :
        db_cursor.execute(query)    
        columns = [column[0] for column in db_cursor.description]
        data = [dict(zip(columns, row)) for row in db_cursor.fetchall()]
    
        # self.db_connect.close()
    except sqlite3.Error as e:
        print('SQLite error: %s' % (' '.join(e.args)))
        print("Exception class is: ", e.__class__)
        print('SQLite traceback: ')
        exc_type, exc_value, exc_tb = sys.exc_info()
        data = []
    
    finally:
        # db_connect.commit()
        # auto_increment and delete on cascade https://stackoverflow.com/questions/29037793/sqlite-integrityerror-unique-constraint-failed
        db_cursor.close()
        # db_cursor.close()
        # print('Read Query!')
    return data
# data =get_query(db_connect,query)
# pd.DataFrame(data)

def generate_token_query(letter,talbe_name):
    query =f"""
    SELECT * FROM {talbe_name} 
    WHERE Devanagari == '{letter}'
        OR Bengali–Assamese == '{letter}'
        OR Gujarati == '{letter}'
        OR Kannada == '{letter}'
        OR Malayalam == '{letter}'
        OR Odia == '{letter}'
        OR Tamil == '{letter}'
        OR Telugu == '{letter}'
    """
    # print(query.replace('\n','').replace("  ","").replace('OR',' OR')) 
# SELECT * FROM IndianAlphabet WHERE Devanagari == 'ध' OR Bengali–Assamese == 'ध' OR Gujarati == 'ध' OR Kannada == 'ध' OR Malayalam == 'ध' OR Odia == 'ध' OR Tamil == 'ध' OR Telugu == 'ध'    
    return query

# %%
# Devanagari Bengali–Assamese Gujarati Gurmukhi Kannada Malayalam Nastaliq Odia Sinhala Tamil Telugu 

# talbe_name = 'IndianAlphabet'
talbe_name = 'Barakhadi'
# letter1 = letter
# letter1='া'
letter1 = 'ŭ'
query = f"SELECT * FROM {talbe_name} WHERE IAST='{letter1}'" 
data =get_query(db_connect,query)
del data[0]['IAST']
halant_list = []
for value in data[0].values():
    if value is not None and value not in halant_list:
        halant_list.append(value)
halant_list
# Out:
# ['्', '্', '્', '್', '്', '୍', '్']

# %%
for i in halant_list:
    print(f'letter= {i}\t| ascii(letter) ={ord(i)}')
# ord(halant_list[1])

# letter= ଶ 	| ascii(letter) =2870	| iast = śa
# letter= ୍ 	| ascii(letter) =2893	| iast = ୍
# letter= ଚ 	| ascii(letter) =2842	| iast = ca
# letter= ષ 	| ascii(letter) =2743	| iast = ṣa
# letter= ્ 	| ascii(letter) =2765	| iast = ્
# letter= ટ 	| ascii(letter) =2719	| iast = ṭa
# Out:
# letter= ्	| ascii(letter) =2381
# letter= ্	| ascii(letter) =2509
# letter= ્	| ascii(letter) =2765
# letter= ್	| ascii(letter) =3277
# letter= ്	| ascii(letter) =3405
# letter= ୍	| ascii(letter) =2893
# letter= ్	| ascii(letter) =3149

# %%
# line = 'ధృత్రాష్ట్ర ఉవాచ'
def generate_token(db_connect, line):
    output_token = ''
    for letter in line: # line
        talbe_name = 'IndianAlphabet'
        query = generate_token_query(letter,talbe_name)    
        alpha_token =get_query(db_connect,query)
    
        talbe_name = 'Barakhadi'
        query = generate_token_query(letter,talbe_name)    
        barakhadi_token =get_query(db_connect,query)
        
        if len(alpha_token) !=0:
            output_token += alpha_token[0]['IAST']
            # print(alpha_token[0]['IAST'],end='')
        elif letter in  halant_list and output_token[-1] in "a": # if 'क '
            output_token = output_token[:-1]
        elif len(barakhadi_token) !=0 and output_token[-1] in "a":
            output_token = output_token[:-1]+ barakhadi_token[0]['IAST']
        elif len(barakhadi_token) !=0 :
            output_token += barakhadi_token[0]['IAST'].replace("a",'')
        elif len(barakhadi_token) ==0  and len(alpha_token) ==0 and ord(letter)==8205: # cleaing data
            pass
        else:
            # print(f"""NOT Present in alpha and barakadi{letter}=={ord(letter)} """)
            output_token += letter
        # print(out)
        # print(f'{letter}\t| {output_token}')
    # print(f'{line}\t| {output_token}')
    return output_token
# generate_token(db_connect, line)

# %%
# for line in text_telugu.strip().split('\n'):
# source : https://hinduliterature.org/tamil/scriptures/srimad_bhagawad_gita_chapter_1.php
file_name ='bg-hinid'
with open (file_name,'r') as f:
   f_hindi = f.read()  

file_name ='bg-kannada'
with open (file_name,'r') as f:
   f_kanada = f.read()  

file_name ='bg-malayalam'
with open (file_name,'r') as f:
   f_malayalam = f.read()  

file_name ='bg-telugu'
with open (file_name,'r') as f:
   f_telugu = f.read()  

file_name ='bg-oriya'
with open (file_name,'r') as f:
   f_oriya = f.read()  

file_name ='bg-bengali'
with open (file_name,'r') as f:
   f_bengali = f.read()  

file_name ='bg-gujarati'
with open (file_name,'r') as f:
   f_gujarati = f.read()  

file_name ='bg-tamil'
with open (file_name,'r') as f:
   f_tamil = f.read()  

print(len( f_telugu.split('\n')),len(f_kanada.split('\n')), len(f_malayalam.split('\n')), len(f_hindi.split('\n')  ))

min_len  = min(len( f_telugu.split('\n')),len(f_kanada.split('\n')), len(f_malayalam.split('\n')), len(f_hindi.split('\n')  ))

for line_idx in range(min_len):
    # print(line_idx)
    print("-"*40)
    line = f_telugu.strip().split('\n')[line_idx]
    if len(line):
        print(f"""TEL: {line.strip()}\t| {generate_token(db_connect, line)} """)
    line = f_kanada.strip().split('\n')[line_idx]
    if len(line):
        print(f"""KAN: {line.strip()}\t| {generate_token(db_connect, line)} """)
    line = f_malayalam.strip().split('\n')[line_idx]
    if len(line):
        print(f"""MAL: {line.strip()}\t| {generate_token(db_connect, line)} """)
    line = f_hindi.strip().split('\n')[line_idx]
    if len(line):
        print(f"""HIN: {line.strip()}\t| {generate_token(db_connect, line)} """)

    line = f_oriya.strip().split('\n')[line_idx]
    if len(line):
        print(f"""ORI: {line.strip()}\t| {generate_token(db_connect, line)} """)

    line = f_bengali.strip().split('\n')[line_idx]
    if len(line):
        print(f"""BEN: {line.strip()}\t| {generate_token(db_connect, line)} """)
        
    line = f_gujarati.strip().split('\n')[line_idx]
    if len(line):
        print(f"""GUJ: {line.strip()}\t| {generate_token(db_connect, line)} """)

    line = f_tamil.strip().split('\n')[line_idx]
    if len(line):
        print(f"""TAM: {line.strip()}\t| {generate_token(db_connect, line)} """)
# Out:
# 157 469 157 140
# ----------------------------------------
# TEL: ధృతరాష్ట్ర ఉవాచ |	| dhr̥tarāṣṭra uvāca |
# KAN: ಧೃತರಾಷ್ಟ್ರ ಉವಾಚ ।	| dhr̥tarāṣṭra uvāca |
# MAL: ധൃതരാഷ്ട്ര ഉവാച ।	| dhr̥tarāṣṭra uvāca |
# HIN: धृतराष्ट्र उवाच	| dhr̥tarāṣṭra uvāca
# ORI: ଧୃତରାଷ୍ଟ୍ର ଉଵାଚ |	| dhr̥tarāṣṭra uvāca |
# BEN: ধৃতরাষ্ট্র উবাচ |	| dhr̥tarāṣṭra ubāca |
# GUJ: ધૃતરાષ્ટ્ર ઉવાચ |	| dhr̥tarāṣṭra uvāca |
# TAM: த்றுதராஷ்ட்ர உவாச |	| ta்ṟutarāṣa்ṭa்ra uvāca |
# ----------------------------------------
# KAN: ಧರ್ಮಕ್ಷೇತ್ರೇ ಕುರುಕ್ಷೇತ್ರೇ ಸಮವೇತಾ ಯುಯುತ್ಸವಃ ।	| dharmakṣētrē kurukṣētrē samavētā yuyutsavaḥ |
# MAL: ധർമക്ഷേത്രേ കുരുക്ഷേത്രേ സമവേതാ യുയുത്സവഃ ।	| dhaṟmakṣētrē kurukṣētrē samavētā yuyutsavaḥ |
# HIN: धर्मक्षेत्रे कुरुक्षेत्रे समवेता युयुत्सव: ।	| dharmakṣētrē kurukṣētrē samavētā yuyutsavaḥ |
# ORI: ଧର୍ମକ୍ଷେତ୍ରେ କୁରୁକ୍ଷେତ୍ରେ ସମଵେତା ୟୁୟୁତ୍ସଵଃ |	| dharmakṣētrē kurukṣētrē samavētā ẏuẏutsavaḥ |
# BEN: ধর্মক্ষেত্রে কুরুক্ষেত্রে সমবেতা য়ুয়ুত্সবঃ |	| dharmakṣētrē kurukṣētrē samabētā ẏuẏutsabaḥ |
# ...

# %%
# Correction need to be made IN tokenization
text = """BEN: ধর্মক্ষেত্রে কুরুক্ষেত্রে সমবেতা য়ুয়ুত্সবঃ 
BEN: ধর্মক্ষেত্রে কুরুক্ষেত্রে সমবেতা য়ুয়ুত্সবঃ 
BEN: য়ুয়ুধানো বিরাটশ্চ দ্রুপদশ্চ মহারথঃ
GUJ: મામકાઃ પાંડવાશ્ચૈવ કિમકુર્વત સંજય 
ORI: ମାମକାଃ ପାଂଡଵାଶ୍ଚୈଵ କିମକୁର୍ଵତ ସଂଜୟ
KAN: ವ್ಯೂಢಾಂ ದ್ರುಪದಪುತ್ರೇಣ ತವ ಶಿಷ್ಯೇಣ ಧೀಮತಾ ॥ 1-3 ॥	| vyūḍhāṁ drupadaputrēṇa tava śiṣyēṇa dhīmatā || 1-3 || 
MAL: വ്യൂഢാം ദ്രുപദപുത്രേണ തവ ശിഷ്യേണ ധീമതാ ॥ 1-3 ॥	# | vyaൂḍhāṁ drupadaputrēṇa tava śiṣyēṇa dhīmatā || 1-3 ||
KAN: ನಭಶ್ಚ ಪೃಥಿವೀಂ ಚೈವ ತುಮುಲೋಽಭ್ಯನುನಾದಯನ್ ॥ 1-19 ॥ orಲೋ ವ್ಯನು	| nabhaśca pr̥thivīṁ caiva tumulōʼbhyanunādayan || 1-19 || orlō vyanu 
MAL: നഭശ്ച പൃഥിവീം ചൈവ തുമുലോഽഭ്യനുനാദയൻ ॥ 1-19 ॥ orലോ വ്യനു	| nabhaśca pr̥thivīṁ caiva tumulōʼbhyanunādayaൻ ||
TAM: தர்மக்ஷேத்ரே குருக்ஷேத்ரே ஸமவேதா யுயுத்ஸவஃ |	
TAM: தார்தராஷ்ட்ரஸ்ய துர்புத்தேர்யுத்தே ப்ரியசிகீர்ஷவஃ || 23 ||	| tāra்tarāṣa்ṭa்rasa்ya tura்puta்tēra்yuta்tē pa்riyacikīra்ṣavaḵa || 23 ||"""
# text
print(generate_token(db_connect, text))
# Out:
# BENḥ dharmakṣētrē kurukṣētrē samabētā য়uয়utsabaḥ
# BENḥ dharmakṣētrē kurukṣētrē samabētā য়uয়utsabaḥ
# BENḥ য়uয়udhāno birāṭaśca drupadaśca mahārathaḥ
# GUJḥ māmakāḥ pāṁḍavāśa્caiva kimakura્vata saṁjaya
# ORIḥ māmakāḥ pāṁḍavāśa୍caiva kimakura୍vata saṁjaẏa
# KANḥ vyūḍhāṁ drupadaputrēṇa tava śiṣyēṇa dhīmatā || 1-3 ||	| vyūḍhāṁ drupadaputrēṇa tava śiṣyēṇa dhīmatā || 1-3 ||
# MALḥ vyaൂḍhāṁ drupadaputrēṇa tava śiṣyēṇa dhīmatā || 1-3 ||	# | vyaൂḍhāṁ drupadaputrēṇa tava śiṣyēṇa dhīmatā || 1-3 ||
# KANḥ nabhaśca pr̥thivīṁ caiva tumulōʼbhyanunādayan || 1-19 || orlō vyanu	| nabhaśca pr̥thivīṁ caiva tumulōʼbhyanunādayan || 1-19 || orlō vyanu
# MALḥ nabhaśca pr̥thivīṁ caiva tumulōʼbhyanunādayaൻ || 1-19 || orlō vyanu	| nabhaśca pr̥thivīṁ caiva tumulōʼbhyanunādayaൻ ||
# TAMḥ tara்maka்ṣēta்rē kuruka்ṣēta்rē samavētā yuyuta்savaḵa |
# TAMḥ tāra்tarāṣa்ṭa்rasa்ya tura்puta்tēra்yuta்tē pa்riyacikīra்ṣavaḵa || 23 ||	| tāra்tarāṣa்ṭa்rasa்ya tura்puta்tēra்yuta்tē pa்riyacikīra்ṣavaḵa || 23 ||

# %%
# text = """ମାମକାଃ ପାଂଡଵାଶ୍ଚୈଵ କିମକୁର୍ଵତ ସଂଜୟ"""
text =' ധർമക്ഷേത്രേ കുരുക്ഷേത്രേ സമവേതാ യുയുത്സവഃ ।' #	| dhaർmakṣētrē kurukṣētrē samavētā yuyutsavaḥ |  
for idx, letter in enumerate(text): 
    # print(
    # letter=text[idx:idx+2]
    # iast_letter = generate_token(db_connect, letter)
    # print(letter, iast_letter)
    talbe_name = 'IndianAlphabet'
    query = generate_token_query(letter,talbe_name)    
    alpha_token =get_query(db_connect,query)

    talbe_name = 'Barakhadi'
    query = generate_token_query(letter,talbe_name)    
    barakhadi_token =get_query(db_connect,query)
    output_token=''
    if len(alpha_token) !=0:
        output_token += alpha_token[0]['IAST']
        # print(alpha_token[0]['IAST'],end='')
    elif len(barakhadi_token) !=0 :
        output_token = output_token[:-1]+ barakhadi_token[0]['IAST']
    else:
        output_token = letter
        
    output = f'letter= {letter} \t| ascii(letter) ={ord(letter[0])}\t| iast = {output_token}' #  | ascii(iast)={ord(iast_letter)}'
    print(output)
    # āśa୍c r # letter=୍ 	| ascii(letter) =2893   | iast = ୍
    # letter= ্ 	| ascii(letter) =2509	| iast = ŭ
# letter= য় 	| ascii(letter) =2527	| iast = য়
# letter= ূ 	| ascii(letter) =2498	| iast = ū
# Out:
# letter=   	| ascii(letter) =32	| iast =
# letter= ധ 	| ascii(letter) =3367	| iast = dha
# letter= ർ 	| ascii(letter) =3452	| iast = ṟa
# letter= മ 	| ascii(letter) =3374	| iast = ma
# letter= ക 	| ascii(letter) =3349	| iast = ka
# letter= ് 	| ascii(letter) =3405	| iast = ŭ
# letter= ഷ 	| ascii(letter) =3383	| iast = ṣa
# letter= േ 	| ascii(letter) =3399	| iast = ē
# letter= ത 	| ascii(letter) =3364	| iast = ta
# letter= ് 	| ascii(letter) =3405	| iast = ŭ
# letter= ര 	| ascii(letter) =3376	| iast = ra
# letter= േ 	| ascii(letter) =3399	| iast = ē
# letter=   	| ascii(letter) =32	| iast =
# letter= ക 	| ascii(letter) =3349	| iast = ka
# letter= ു 	| ascii(letter) =3393	| iast = u
# letter= ര 	| ascii(letter) =3376	| iast = ra
# letter= ു 	| ascii(letter) =3393	| iast = u
# letter= ക 	| ascii(letter) =3349	| iast = ka
# letter= ് 	| ascii(letter) =3405	| iast = ŭ
# letter= ഷ 	| ascii(letter) =3383	| iast = ṣa
# letter= േ 	| ascii(letter) =3399	| iast = ē
# ...

# %% [markdown]
# # Stemming Algorithum
# <div  style='  position: relative;'>
#   <img style= 'position: absolute; top: 0px;right: 0px; width: 50%; height: auto; opacity: 0.8;' src="Screenshots_2023-11-23T16-02-43.png" alt="Cinque Terre" width="1000" height="300">
# </div>
#
#
# Ambiguity:(meaning) more than one possibility <br>
# Different Phonetic Ambiguity
# -  Vowels(svara [स्वरा] ) Ambiguity:
#     - a: [अ a , आ ā A] ,
#     - i & e:[ इ i(e), ई ī(ee) ]
#     - u:[उ u, ऊ ū ]
#     - r:[ऋ ṛ, ॠ ṝ, र ra ]
#     - l:[ऌ ḷ, ॡ ḹ,ल la, ळ ḻ]
# -   Consonants vyañjanā [व्यञ्जना] Ambiguity
#     - [क ka,ख kha ] simillar for all consonants
#     - n : [ङ ṅa, ञ ña, ण ṇa, न na ]
#     - t : [ट ṭa, ठ ṭha,त ta,थ tha,  ]
#     - d : [ड ḍa,ढ ḍha, द da, ध dha]
#     - s : [श śa, ष ṣa, स sa ]
# - Sandhi Ambiguity
#   -  svara sandhih
#   -  vyanjana sandhih
#   -  visarga sandhih
#
# Basic,Broad      <br>
# NO vowel    <br>
# trucated constant eg: k =k, kh as one <br>
#
# Narrow   <br>
# truncated vowel eg:  <br>
# truncated constant <br>
#
# Specific <br>
# origina word <br>

# %%
search_word = ' Dhritirashtra ' # dhr̥tarāṣṭra uvāca

db_data = """
TEL= ధృతరాష్ట్ర ఉవాచ |
KAN= ಧೃತರಾಷ್ಟ್ರ ಉವಾಚ ।	 
MAL= ധൃതരാഷ്ട്ര ഉവാച ।	 
HIN= धृतराष्ट्र उवाच	|
ORI= ଧୃତରାଷ୍ଟ୍ର ଉଵାଚ | 
BEN= ধৃতরাষ্ট্র উবাচ |	 
GUJ= ધૃતરાષ્ટ્ર ઉવાચ |	
TAM= த்றுதராஷ்ட்ர உவாச |	
"""
data_token = generate_token(db_connect, db_data)
print('data token: ',data_token)
# Data Cleaning : 
search_word = search_word.lower().strip()
db_data = db_data.lower().strip()
# if possible: replace <chr(8205)> with '' in search_word, db_data


# steamming : 

    # part-I : replace_m2o (original= '' or [] , dest='') # replace many to one
        # replace_m2m(dict) # 
# print(f'abc{chr(8205)}abc' )
# 
[]

# print(search_word, db_data)

# for line in db_data.split('\n'):
#     line_token = generate_token(db_connect, line)
#     print(f"""{line.strip()}\t| {line_token} """)
dest = 's'
source = basic_truncated_consonat[dest]
print(source, dest)
def replace_m2o(text, source=source, dest=dest):
    # text = data_token
    if isinstance(source, list):
        for source_letter in source:
            text = text.replace(source_letter,dest)
    elif isinstance(source, str):
        text = text.replace(source,dest)
    # print(text)
    return text
# def replace_m2m(text,info_dic):
    

# replace_m2o(data_token, source=source, dest=dest)

# output_data = data_token
def replace_m2m(output_data,info_dict):
    for dest in info_dict.keys():
        source = info_dict[dest]
        output_data = replace_m2o(output_data, source=source, dest=dest)
    return output_data

basic_stem_dict = zero_vowels
basic_stem_dict.update(basic_truncated_consonat)
print(replace_m2m(data_token,basic_stem_dic))

normal_stem_dict = trucated_vowels
normal_stem_dict.update(basic_truncated_consonat)
print(replace_m2m(data_token,normal_stem_dict))

# print(output_data)
# db_data
# for line in db_data:
# ord('ః')
# Out:
# data token:
# TEL= dhr̥tarāṣṭra uvāca |
# KAN= dhr̥tarāṣṭra uvāca |
# MAL= dhr̥tarāṣṭra uvāca |
# HIN= dhr̥tarāṣṭra uvāca	|
# ORI= dhr̥tarāṣa୍ṭa୍ra uvāca |
# BEN= dhr̥tarāṣa্ṭa্ra ubāca |
# GUJ= dhr̥tarāṣa્ṭa્ra uvāca |
# TAM= ta்ṟutarāṣa்ṭa்ra uvāca |
#
# ['ś', 'ṣ', 's', 's̱', 's̤', 'sh'] s
#
# TEL= dtrstr vc |
# KAN= dtrstr vc |
# MAL= dtrstr vc |
# HIN= dtrstr vc	|
# ORI= dtrs୍t୍r vc |
# BEN= dtrs্t্r bc |
# GUJ= dtrs્t્r vc |
# TAM= t்rtrs்t்r vc |
#
#
# TEL= dr̥tarāstra uvāca |
# KAN= dr̥tarāstra uvāca |
# MAL= dr̥tarāstra uvāca |
# HIN= dr̥tarāstra uvāca	|
# ORI= dr̥tarāsa୍ta୍ra uvāca |
# BEN= dr̥tarāsa্ta্ra ubāca |
# GUJ= dr̥tarāsa્ta્ra uvāca |
# TAM= ta்rutarāsa்ta்ra uvāca |

# %%
# math.nan == 
# type(halant_list[3])
# barakhadi.loc['ŭ'].unique()
# barakhadi.loc['ŭ'].unique().dropna()

# trucated_vowels = { 'a':["ā", "â"],  'i':["i", "ī"], 'u':["u", "ū"], 'r':["r̥", "r̥̄"],'l':["l̥", "l̥̄"],"e":["e", "ē", "ê"],"o": ["o", "ō", "ô"], 'm' :["ṁ",  "m̐", "ṃ", "ṃ"], 'n': ["n̆", "n̆", "n̆"], 'h' :["ḥ" , "ḫ", "ẖ", "ḥ"]}

# trucated_vowels = {'':'asdfa'}
# trucated_vowels['']
zero_vowels={ '':['a', "ā", "â","i", "ī","u", "ū","r̥", "r̥̄","l̥", "l̥̄","e", "ē", "ê","o", "ō", "ô","ṁ", "m̐", "ṃ", "ṃ","n̆", "n̆", "n̆","ḥ" , "ḫ", "ẖ", "ḥ"],
}

truncated_vowels = {
'a':["ā", "â"], 
'i':["i", "ī"], 
'u':["u", "ū"], 
'r':["r̥", "r̥̄"],
'l':["l̥", "l̥̄"],
"e":["e", "ē", "ê"],
        # "ai", 
"o": ["o", "ō", "ô"], 
                        # "au",
'm' :["ṁ", "m̐", "ṃ", "ṃ"], 
'n': ["n̆", "n̆", "n̆"], 
'h' :["ḥ" , "ḫ", "ẖ", "ḥ"],
}

basic_truncated_consonat = {
'k' : ['ḵ', 'k', 'kh','k͟ha'],
'g' :['g','g̈','gh','ġ'],
'n' : ['ṅ','n̆','ñ','ṇ','ṉ'],
'c' : ['c', 'ĉ','ch','ĉh'],
'j' : ['j','ǰ', 'ĵ', 'jh'],
't': ['ṭ','ṭa','t','th','ṯ','t̤'],
'd' : ['ḍ', 'd̤','ḍ','ḍh','d','dh','ḏ'],
'p' : ['p', 'ph'],
'b' : [ 'b', 'b̤', 'bh'],
'm' : ['m̆' ],
'r' : ['ṟ', 'r̆'],
'l' :['ḻ', 'ḷ', 'l̤'],
'y' : ['y', 'ẏ', 'y̌'],
's': ['ś', 'ṣ', 's','s̱', 's̤','sh' ],
"z": ["z","ž","ž","ž",'ẕ','ẕ','ẓ','ż'],
'h' : ['h','h̤']
}
print(basic_truncated_consonat, trucated_vowels,zero_vowels)
# Out:
# {'k': ['ḵ', 'k', 'kh', 'k͟ha'], 'g': ['g', 'g̈', 'gh', 'ġ'], 'n': ['ṅ', 'n̆', 'ñ', 'ṇ', 'ṉ'], 'c': ['c', 'ĉ', 'ch', 'ĉh'], 'j': ['j', 'ǰ', 'ĵ', 'jh'], 't': ['ṭ', 'ṭa', 't', 'th', 'ṯ', 't̤'], 'd': ['ḍ', 'd̤', 'ḍ', 'ḍh', 'd', 'dh', 'ḏ'], 'p': ['p', 'ph'], 'b': ['b', 'b̤', 'bh'], 'm': ['m̆'], 'r': ['ṟ', 'r̆'], 'l': ['ḻ', 'ḷ', 'l̤'], 'y': ['y', 'ẏ', 'y̌'], 's': ['ś', 'ṣ', 's', 's̱', 's̤', 'sh'], 'z': ['z', 'ž', 'ž', 'ž', 'ẕ', 'ẕ', 'ẓ', 'ż'], 'h': ['h', 'h̤']} {'': 'asdfa'} {'': ['a', 'ā', 'â', 'i', 'ī', 'u', 'ū', 'r̥', 'r̥̄', 'l̥', 'l̥̄', 'e', 'ē', 'ê', 'o', 'ō', 'ô', 'ṁ', 'm̐', 'ṃ', 'ṃ', 'n̆', 'n̆', 'n̆', 'ḥ', 'ḫ', 'ẖ', 'ḥ']}

# %%
text = '''धृतराष्ट्र उवाच
धर्मक्षेत्रे कुरुक्षेत्रे समवेता युयुत्सव: ।
मामका: पाण्डवाश्चैव किमकुर्वत सञ्जय ॥ १ ॥

सञ्जय उवाच
दृष्ट्वा तु पाण्डवानीकं व्यूढं दुर्योधनस्तदा ।
आचार्यमुपसङ्गम्य राजा वचनमब्रवीत् ॥ २ ॥

पश्यैतां पाण्डुपुत्राणामाचार्य महतीं चमूम् ।
व्यूढां द्रुपदपुत्रेण तव शिष्येण धीमता ॥ ३ ॥
TEXT 4
अत्र श‍ूरा महेष्वासा भीमार्जुनसमा युधि ।
युयुधानो विराटश्च द्रुपदश्च महारथः ॥ ४ ॥
TEXT 5
धृष्टकेतुश्चेकितानः काशिराजश्च वीर्यवान् ।
पुरुजित्कुन्तिभोजश्च शैब्यश्च नरपुङ्गवः ॥ ५ ॥
TEXT 6
युधामन्युश्च विक्रान्त उत्तमौजाश्च वीर्यवान् ।
सौभद्रो द्रौपदेयाश्च सर्व एव महारथाः ॥ ६ ॥
TEXT 7
अस्माकं तु विशिष्टा ये तान्निबोध द्विजोत्तम ।
नायका मम सैन्यस्य संज्ञार्थ तान्ब्रवीमि ते ॥ ७ ॥
TEXT 8
भवान्भीष्मश्च कर्णश्च कृपश्च समितिंजयः ।
ತಸ್ಮಾತ್ಸರ್ವಗತಂ ಬ್ರಹ್ಮ ನಿತ್ಯಂ ಯಜ್ಞೇ ಪ್ರತಿಷ್ಠಿತಂ ॥ 3-15 ॥

ಏವಂ ಪ್ರವರ್ತಿತಂ ಚಕ್ರಂ ನಾನುವರ್ತಯತೀಹ ಯಃ ।
ಅಘಾಯುರಿಂದ್ರಿಯಾರಾಮೋ ಮೋಘಂ ಪಾರ್ಥ ಸ ಜೀವತಿ ॥ 3-16 ॥

ಯಸ್ತ್ವಾತ್ಮರತಿರೇವ ಸ್ಯಾದಾತ್ಮತೃಪ್ತಶ್ಚ ಮಾನವಃ ।
ಆತ್ಮನ್ಯೇವ ಚ ಸಂತುಷ್ಟಸ್ತಸ್ಯ ಕಾರ್ಯಂ ನ ವಿದ್ಯತೇ ॥ 3-17 ॥

ನೈವ ತಸ್ಯ ಕೃತೇನಾರ್ಥೋ ನಾಕೃತೇನೇಹ ಕಶ್ಚನ ।
ನ ಚಾಸ್ಯ ಸರ್ವಭೂತೇಷು ಕಶ್ಚಿದರ್ಥವ್ಯಪಾಶ್ರಯಃ ॥ 3-18 ॥ 
"""

# %%
text ="""
ധൃതരാഷ്ട്ര ഉവാച ।

ധർമക്ഷേത്രേ കുരുക്ഷേത്രേ സമവേതാ യുയുത്സവഃ ।
മാമകാഃ പാണ്ഡവാശ്ചൈവ കിമകുർവത സഞ്ജയ ॥ 1-1 ॥

സഞ്ജയ ഉവാച ।

ദൃഷ്ട്വാ തു പാണ്ഡവാനീകം വ്യൂഢം ദുര്യോധനസ്തദാ ।
ആചാര്യമുപസംഗമ്യ രാജാ വചനമബ്രവീത് ॥ 1-2 ॥

പശ്യൈതാം പാണ്ഡുപുത്രാണാമാചാര്യ മഹതീം ചമൂം ।
വ്യൂഢാം ദ്രുപദപുത്രേണ തവ ശിഷ്യേണ ധീമതാ ॥ 1-3 ॥

അത്ര ശൂരാ മഹേഷ്വാസാ ഭീമാർജുനസമാ യുധി ।
യുയുധാനോ വിരാടശ്ച ദ്രുപദശ്ച മഹാരഥഃ ॥ 1-4 ॥

ധൃഷ്ടകേതുശ്ചേകിതാനഃ കാശിരാജശ്ച വീര്യവാൻ ।
പുരുജിത്കുന്തിഭോജശ്ച ശൈബ്യശ്ച നരപുംഗവഃ ॥ 1-5 ॥

യുധാമന്യുശ്ച വിക്രാന്ത ഉത്തമൗജാശ്ച വീര്യവാൻ ।
സൗഭദ്രോ ദ്രൗപദേയാശ്ച സർവ ഏവ മഹാരഥാഃ ॥ 1-6 ॥

അസ്മാകം തു വിശിഷ്ടാ യേ താന്നിബോധ ദ്വിജോത്തമ ।
നായകാ മമ സൈന്യസ്യ സഞ്ജ്ഞാർഥം താൻബ്രവീമി തേ ॥ 1-7 ॥

ഭവാൻഭീഷ്മശ്ച കർണശ്ച കൃപശ്ച സമിതിഞ്ജയഃ ।
അശ്വത്ഥാമാ വികർണശ്ച സൗമദത്തിസ്തഥൈവ ച ॥ 1-8 ॥

അപി ത്രൈലോക്യരാജ്യസ്യ ഹേതോഃ കിം നു മഹീകൃതേ ॥ 1-35 ॥

നിഹത്യ ധാർതരാഷ്ട്രാന്നഃ കാ പ്രീതിഃ സ്യാജ്ജനാർദന ।
പാപമേവാശ്രയേദസ്മാൻഹത്വൈതാനാതതായിനഃ ॥ 1-36 ॥

തസ്മാന്നാർഹാ വയം ഹന്തും ധാർതരാഷ്ട്രാൻസ്വബാന്ധവാൻ ।
സ്വജനം ഹി കഥം ഹത്വാ സുഖിനഃ സ്യാമ മാധവ ॥ 1-37 ॥

യദ്യപ്യേതേ ന പശ്യന്തി ലോഭോപഹതചേതസഃ ।
കുലക്ഷയകൃതം ദോഷം മിത്രദ്രോഹേ ച പാതകം ॥ 1-38 ॥

കഥം ന ജ്ഞേയമസ്മാഭിഃ പാപാദസ്മാന്നിവർതിതും ।
കുലക്ഷയകൃതം ദോഷം പ്രപശ്യദ്ഭിർജനാർദന ॥ 1-39 ॥

കുലക്ഷയേ പ്രണശ്യന്തി കുലധർമാഃ സനാതനാഃ ।
ധർമേ നഷ്ടേ കുലം കൃത്സ്നമധർമോഽഭിഭവത്യുത ॥ 1-40 ॥

അധർമാഭിഭവാത്കൃഷ്ണ പ്രദുഷ്യന്തി കുലസ്ത്രിയഃ ।
സ്ത്രീഷു ദുഷ്ടാസു വാർഷ്ണേയ ജായതേ വർണസങ്കരഃ ॥ 1-41 ॥

സങ്കരോ നരകായൈവ കുലഘ്നാനാം കുലസ്യ ച ।
പതന്തി പിതരോ ഹ്യേഷാം ലുപ്തപിണ്ഡോദകക്രിയാഃ ॥ 1-42 ॥

ദോഷൈരേതൈഃ കുലഘ്നാനാം വർണസങ്കരകാരകൈഃ ।
ഉത്സാദ്യന്തേ ജാതിധർമാഃ കുലധർമാശ്ച ശാശ്വതാഃ ॥ 1-43 ॥

ഉത്സന്നകുലധർമാണാം മനുഷ്യാണാം ജനാർദന ।
നരകേ നിയതം വാസോ ഭവതീത്യനുശുശ്രുമ ॥ 1-44 ॥orനരകേഽനിയതം

അഹോ ബത മഹത്പാപം കർതും വ്യവസിതാ വയം ।
യദ്രാജ്യസുഖലോഭേന ഹന്തും സ്വജനമുദ്യതാഃ ॥ 1-45 ॥

യദി മാമപ്രതീകാരമശസ്ത്രം ശസ്ത്രപാണയഃ ।
ധാർതരാഷ്ട്രാ രണേ ഹന്യുസ്തന്മേ ക്ഷേമതരം ഭവേത് ॥ 1-46 ॥

സഞ്ജയ ഉവാച ।

ഏവമുക്ത്വാർജുനഃ സംഖ്യേ രഥോപസ്ഥ ഉപാവിശത് ।
വിസൃജ്യ സശരം ചാപം ശോകസംവിഗ്നമാനസഃ ॥ 1-47 ॥

ഓം തത്സദിതി ശ്രീമദ്ഭഗവദ്ഗീതാസൂപനിഷത്സു
ബ്രഹ്മവിദ്യായാം യോഗശാസ്ത്രേ ശ്രീകൃഷ്ണാർജുനസംവാദേ
അർജുനവിഷാദയോഗോ നാമ പ്രഥമോഽധ്യായഃ ॥ 1 ॥
"""
